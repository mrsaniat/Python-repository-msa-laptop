# %%
#Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#importing dataset
dataset = pd.read_csv('50_Startups.csv')

#show dataset
#print(dataset)

#create independent variable vector (country age salary)
X = dataset.iloc[:,:-1].values
X1 = dataset.iloc[:,:-1]

#create dependent variable vector (Purchased)
Y = dataset.iloc[:,4].values     #try:
Y1 = dataset.iloc[:,4]

#check what is in the X and X1:
#print('\n ---- this is the seperator ---- \n')
#print("\n Value of X:\n",X)

#print('\n ---- this is the seperator ---- \n')
#print("Value of X:",X)

#create dependent variable now
#print('\n ---- this is the seperator ---- \n')
#print("\n Value of Y:\n",Y)



############ PART-2 ############
#encoding the Independant Variable
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_x = LabelEncoder()                                  #does this
X[:,3] = labelencoder_x.fit_transform(X[:,3])                    #does that

# labelencoder_y = LabelEncoder()                                  #does this
# Y = labelencoder_y.fit_transform(Y)                    #does that

onehotencoder = OneHotEncoder(categorical_features = [3])
X = onehotencoder.fit_transform(X).toarray()

#print(" \n Encoded Country: \n", X)

#avoid dummy variable trap
# X = X[:, 1:]

# print(" \n Encoded Country: \n", X)
# print(" \n Purchase Label: \n", Y)




########### PART-3 ##############

#splitting dataset into Training set and Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)

print(" \n X_train: \n", X_train)
print(" \n Y_test: \n", Y_test)


########## PART-4 ###############
# apply multiple linear regression

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,Y_train)


######### PART-5 ################

# test the multiple linear regression

Y_pred = regressor.predict(X_test)
#print(Y_test)
#print(Y_pred)

########## PART-6 ################
# improve the model by backward elimination

import statsmodels.formula.api as sm
X = np.append( arr = np.ones((50,1), dtype = int), values = X, axis = 1)
#print("\n value of X: \n", X)
# also try:
#X = np.append( arr = np.ones((50,1), dtype = int), values = X , axis = 1) 

print("\n value of X: \n", X)

##start from Section 5, Lecture 42
# Out:
#
#  X_train:
#  [[  0.00000000e+00   1.00000000e+00   0.00000000e+00   5.54939500e+04
#     1.03057490e+05   2.14634810e+05]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00   4.60140200e+04
#     8.50474400e+04   2.05517640e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   7.53288700e+04
#     1.44135980e+05   1.34050070e+05]
#  [  1.00000000e+00   0.00000000e+00   0.00000000e+00   4.64260700e+04
#     1.57693920e+05   2.10797670e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   9.17491600e+04
#     1.14175790e+05   2.94919570e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   1.30298130e+05
#     1.45530060e+05   3.23876680e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   1.19943240e+05
#     1.56547420e+05   2.56512920e+05]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00   1.00023000e+03
#     1.24153040e+05   1.90393000e+03]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00   5.42050000e+02
# ...
