# %%
#data preprocessing - Part1:Loading Data and Creating Vectors


#Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#importing dataset
dataset = pd.read_csv('Data.csv')

#show dataset
print(dataset)

#create independent variable vector (country age salary)
X = dataset.iloc[:,:-1].values
X1 = dataset.iloc[:,:-1]

#create dependent variable vector (Purchased)
Y = dataset.iloc[:,2].values     #try:
Y1 = dataset.iloc[:,2]

#check what is in the X and X1:
print('\n ---- this is the seperator ---- \n')
print(X)

print('\n ---- this is the seperator ---- \n')
print(X1)

#create dependent variable now
Y = dataset.iloc[:,3].values
print('\n ---- this is the seperator ---- \n')
print(Y)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
#
#  ---- this is the seperator ----
#
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]
#
#  ---- this is the seperator ----
#
#    Country   Age   Salary
# 0   France  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 4  Germany  40.0      NaN
# 5   France  35.0  58000.0
# 6    Spain   NaN  52000.0
# ...

# %%
#data preprocessing - Part2:Cleaning Data

X = dataset.iloc[:,:-1].values
print("imported data X \n",X)
Y = dataset.iloc[:,3].values
print("\n imported data Y \n",Y)

from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)  #does this
imputer = imputer.fit(X[:,1:3])                                   #does that  
X[:,1:3] = imputer.transform(X[:,1:3])                            #does this

print("\n processed missing data: \n",X)

#Dealing with Categorical Data

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_x = LabelEncoder()                                  #does this
X[:,0] = labelencoder_x.fit_transform(X[:,0])                    #does that

#labelencoder_y = LabelEncoder()                                  #does this
Y = labelencoder_y.fit_transform(Y)                    #does that

onehotencoder = OneHotEncoder(categorical_features = [0])
X = onehotencoder.fit_transform(X).toarray()


print(" \n Encoded Country: \n", X)
print(" \n Purchase Label: \n", Y)

#splitting dataset into Training set and Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)

print(" \n X_train: \n", X_train)
print(" \n Y_test: \n", Y_test)

#Feature Scaling = to bring all the variables into the same level
# Out:
# imported data X
#  [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]
#
#  imported data Y
#  ['No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes']
#
#  processed missing data:
#  [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 63777.77777777778]
#  ['France' 35.0 58000.0]
#  ['Spain' 38.77777777777778 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]
#
#  Encoded Country:
#  [[  1.00000000e+00   0.00000000e+00   0.00000000e+00   4.40000000e+01
#     7.20000000e+04]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00   2.70000000e+01
#     4.80000000e+04]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   3.00000000e+01
#     5.40000000e+04]
# ...
